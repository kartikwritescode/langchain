# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_google_genai import GoogleGenerativeAIEmbeddings
from langchain_core.tools import tool
from langchain_core.messages import HumanMessage
import requests
from dotenv import load_dotenv
from langchain_core.tools import InjectedToolArg
from typing import Annotated

# %%
import os
load_dotenv()
EXCHANGE_RATE_API = os.getenv("EXCHANGE_RATE_API")

# %%
# tool create
# 2 tools -> 1 for conversion ; 2 multiplication with value

@tool
def get_conversion_factor(base_currency:str)->float :
    '''This function fetches the currency conversion factor b/w base currency and target curency '''
    url = f"https://v6.exchangerate-api.com/v6/{EXCHANGE_RATE_API}/latest/{base_currency}"
    response = requests.get(url)
    return response.json()
@tool
def convert(base_currency_value:int , conversion_rate:Annotated[float,InjectedToolArg]) -> float:
    '''Given a currency conversion rate this function calculates the target currency value from a given base currency value'''

    return base_currency_value * conversion_rate

# %%
result = get_conversion_factor.invoke({'base_currency':'USD'})
result
# Out:
# {'result': 'success',
#  'documentation': 'https://www.exchangerate-api.com/docs',
#  'terms_of_use': 'https://www.exchangerate-api.com/terms',
#  'time_last_update_unix': 1785110401,
#  'time_last_update_utc': 'Mon, 27 Jul 2026 00:00:01 +0000',
#  'time_next_update_unix': 1785196801,
#  'time_next_update_utc': 'Tue, 28 Jul 2026 00:00:01 +0000',
#  'base_code': 'USD',
#  'conversion_rates': {'USD': 1,
#   'AED': 3.6725,
#   'AFN': 66.022,
#   'ALL': 82.3937,
#   'AMD': 365.8114,
#   'ANG': 1.79,
#   'AOA': 921.3527,
#   'ARS': 1494.3744,
#   'AUD': 1.4304,
#   'AWG': 1.79,
#   'AZN': 1.7009,
#   'BAM': 1.7173,
#   'BBD': 2.0,
#   'BDT': 123.6077,
#   'BGN': 1.7173,
#   'BHD': 0.376,
#   'BIF': 2990.8731,
#   'BMD': 1.0,
#   'BND': 1.2902,
#   'BOB': 11.1515,
#   'BRL': 5.0861,
#   'BSD': 1.0,
#   'BTN': 96.6315,
#   'BWP': 13.7969,
#   'BYN': 2.8735,
#   'BZD': 2.0,
#   'CAD': 1.4087,
#   'CDF': 2289.5607,
#   'CHF': 0.8168,
#   'CLF': 0.02395,
#   'CLP': 946.5279,
#   'CNH': 6.7702,
#   'CNY': 6.7777,
#   'COP': 3207.1885,
#   'CRC': 455.1568,
#   'CUP': 24.0,
#   'CVE': 96.8154,
#   'CZK': 21.208,
#   'DJF': 177.721,
#   'DKK': 6.5512,
#   'DOP': 58.2195,
#   'DZD': 133.4544,
#   'EGP': 51.3023,
#   'ERN': 15.0,
#   'ETB': 160.4386,
#   'EUR': 0.878,
#   'FJD': 2.2495,
#   'FKP': 0.7496,
#   'FOK': 6.5515,
#   'GBP': 0.7495,
#   'GEL': 2.6228,
#   'GGP': 0.7496,
#   'GHS': 11.6363,
#   'GIP': 0.7496,
#   'GMD': 74.4229,
#   'GNF': 8794.4432,
#   'GTQ': 7.6323,
#   'GYD': 209.2108,
#   'HKD': 7.8424,
#   'HNL': 26.8014,
#   'HRK': 6.6155,
#   'HTG': 130.6707,
#   'HUF': 316.9181,
#   'IDR': 17948.109,
#   'ILS': 3.0518,
#   'IMP': 0.7496,
#   'INR': 96.6218,
#   'IQD': 1310.416,
#   'IRR': 1333855.7976,
#   'ISK': 125.7794,
#   'JEP': 0.7496,
#   'JMD': 158.2916,
#   'JOD': 0.709,
#   'JPY': 163.6794,
#   'KES': 129.5581,
#   'KGS': 87.4734,
#   'KHR': 4051.2642,
#   'KID': 1.4306,
#   'KMF': 431.96,
#   'KRW': 1459.962,
#   'KWD': 0.3096,
#   'KYD': 0.8333,
#   'KZT': 475.3851,
#   'LAK': 22421.395,
#   'LBP': 89500.0,
#   'LKR': 336.4151,
#   'LRD': 181.271,
#   'LSL': 16.7671,
#   'LYD': 6.4005,
#   'MAD': 9.3732,
#   'MDL': 17.5825,
#   'MGA': 4324.8508,
#   'MKD': 54.0436,
#   'MMK': 2099.5984,
#   'MNT': 3564.3844,
#   'MOP': 8.0775,
#   'MRU': 40.1288,
#   'MUR': 47.4307,
#   'MVR': 15.4684,
#   'MWK': 1733.3964,
#   'MXN': 17.4504,
#   'MYR': 4.0912,
#   'MZN': 63.5375,
#   'NAD': 16.7671,
#   'NGN': 1366.5907,
#   'NIO': 36.8211,
#   'NOK': 9.5783,
#   'NPR': 154.6103,
#   'NZD': 1.7256,
#   'OMR': 0.3845,
#   'PAB': 1.0,
#   'PEN': 3.4045,
#   'PGK': 4.4389,
#   'PHP': 61.7948,
#   'PKR': 278.0807,
#   'PLN': 3.7911,
#   'PYG': 6052.9232,
#   'QAR': 3.64,
#   'RON': 4.5995,
#   'RSD': 103.2005,
#   'RUB': 77.8264,
#   'RWF': 1468.7607,
#   'SAR': 3.75,
#   'SBD': 8.0327,
#   'SCR': 14.5792,
#   'SDG': 458.4797,
#   'SEK': 9.6999,
#   'SGD': 1.29,
#   'SHP': 0.7496,
#   'SLE': 24.3641,
#   'SLL': 24364.1441,
#   'SOS': 571.3614,
#   'SRD': 37.9724,
#   'SSP': 4900.2076,
#   'STN': 21.5116,
#   'SYP': 121.7792,
#   'SZL': 16.7671,
#   'THB': 33.6573,
#   'TJS': 9.2356,
#   'TMT': 3.5004,
#   'TND': 2.9551,
#   'TOP': 2.3722,
#   'TRY': 47.342,
#   'TTD': 6.7997,
#   'TVD': 1.4306,
#   'TWD': 32.3549,
#   'TZS': 2631.0175,
#   'UAH': 44.8542,
#   'UGX': 3736.836,
#   'UYU': 40.2303,
#   'UZS': 11913.7478,
#   'VES': 742.2292,
#   'VND': 26240.0163,
#   'VUV': 118.5531,
#   'WST': 2.7162,
#   'XAF': 575.9466,
#   'XCD': 2.7,
#   'XCG': 1.79,
#   'XDR': 0.7372,
#   'XOF': 575.9466,
#   'XPF': 104.7765,
#   'YER': 238.2144,
#   'ZAR': 16.7629,
#   'ZMW': 18.6658,
#   'ZWG': 26.6503,
#   'ZWL': 26.6503}}

# %%
convert.invoke({'base_currency_value':10,'conversion_rate':96.6138})
# Out:
# 966.1379999999999

# %%
#Step 2 -> tool binding

# %%
llm = ChatGoogleGenerativeAI(model = 'gemini-3.6-flash')

# %%
llm_with_tools= llm.bind_tools([convert,get_conversion_factor])

# %%
# tool calling
messages=[HumanMessage('What is the conversion factor between usd and inr and based on that can u convert 10 usd to inr')]

# %%
ai_msg = llm_with_tools.invoke(messages)
ai_msg
# Out:
# AIMessage(content=[], additional_kwargs={'function_call': {'name': 'get_conversion_factor', 'arguments': '{"base_currency": "USD"}'}, '__gemini_function_call_thought_signatures__': {'DGvakyrA': '...'}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-3.6-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019fa36d-85e6-7da2-8e56-c4be66c404bb-0', tool_calls=[{'name': 'get_conversion_factor', 'args': {'base_currency': 'USD'}, 'id': 'DGvakyrA', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 146, 'output_tokens': 592, 'total_tokens': 738, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 572}})

# %%
import json

for tool_call in ai_msg.tool_calls:
    # execute the first tool and get the value of conversion rate
    if tool_call['name'] == 'get_conversion_factor':
        tool_msg1 = get_conversion_factor.invoke(tool_call)
        print(tool_msg1)
        # fetch this conv rate
        print(json.loads(tool_msg1.content)['conversion_rates'])

        # append this tool msg to msg list
        messages.append(tool_msg1)
    print('---------------------------------------------------------')
    # execute the second tool using the conv rate from tool 1 
    if tool_call['name'] == 'convert':
        # fetch the current arg
        tool_call['args']['conversion_rates'] = conversion_rate
        tool_message2 = convert.invoke(tool_call)
        messages.append(tool_msg2)
# Out:
# content='{"result": "success", "documentation": "https://www.exchangerate-api.com/docs", "terms_of_use": "https://www.exchangerate-api.com/terms", "time_last_update_unix": 1785110401, "time_last_update_utc": "Mon, 27 Jul 2026 00:00:01 +0000", "time_next_update_unix": 1785196801, "time_next_update_utc": "Tue, 28 Jul 2026 00:00:01 +0000", "base_code": "USD", "conversion_rates": {"USD": 1, "AED": 3.6725, "AFN": 66.022, "ALL": 82.3937, "AMD": 365.8114, "ANG": 1.79, "AOA": 921.3527, "ARS": 1494.3744, "AUD": 1.4304, "AWG": 1.79, "AZN": 1.7009, "BAM": 1.7173, "BBD": 2.0, "BDT": 123.6077, "BGN": 1.7173, "BHD": 0.376, "BIF": 2990.8731, "BMD": 1.0, "BND": 1.2902, "BOB": 11.1515, "BRL": 5.0861, "BSD": 1.0, "BTN": 96.6315, "BWP": 13.7969, "BYN": 2.8735, "BZD": 2.0, "CAD": 1.4087, "CDF": 2289.5607, "CHF": 0.8168, "CLF": 0.02395, "CLP": 946.5279, "CNH": 6.7702, "CNY": 6.7777, "COP": 3207.1885, "CRC": 455.1568, "CUP": 24.0, "CVE": 96.8154, "CZK": 21.208, "DJF": 177.721, "DKK": 6.5512, "DOP": 58.2195, "DZD": 133.4544, "EGP": 51.3023, "ERN": 15.0, "ETB": 160.4386, "EUR": 0.878, "FJD": 2.2495, "FKP": 0.7496, "FOK": 6.5515, "GBP": 0.7495, "GEL": 2.6228, "GGP": 0.7496, "GHS": 11.6363, "GIP": 0.7496, "GMD": 74.4229, "GNF": 8794.4432, "GTQ": 7.6323, "GYD": 209.2108, "HKD": 7.8424, "HNL": 26.8014, "HRK": 6.6155, "HTG": 130.6707, "HUF": 316.9181, "IDR": 17948.109, "ILS": 3.0518, "IMP": 0.7496, "INR": 96.6218, "IQD": 1310.416, "IRR": 1333855.7976, "ISK": 125.7794, "JEP": 0.7496, "JMD": 158.2916, "JOD": 0.709, "JPY": 163.6794, "KES": 129.5581, "KGS": 87.4734, "KHR": 4051.2642, "KID": 1.4306, "KMF": 431.96, "KRW": 1459.962, "KWD": 0.3096, "KYD": 0.8333, "KZT": 475.3851, "LAK": 22421.395, "LBP": 89500.0, "LKR": 336.4151, "LRD": 181.271, "LSL": 16.7671, "LYD": 6.4005, "MAD": 9.3732, "MDL": 17.5825, "MGA": 4324.8508, "MKD": 54.0436, "MMK": 2099.5984, "MNT": 3564.3844, "MOP": 8.0775, "MRU": 40.1288, "MU
, 'JOD': 0.709, 'JPY': 163.6794, 'KES': 129.5581, 'KGS': 87.4734, 'KHR': 4051.2642, 'KID': 1.4306, 'KMF': 431.96, 'KRW': 1459.962, 'KWD': 0.3096, 'KYD': 0.8333, 'KZT': 475.3851, 'LAK': 22421.395, 'LBP': 89500.0, 'LKR': 336.4151, 'LRD': 181.271, 'LSL': 16.7671, 'LYD': 6.4005, 'MAD': 9.3732, 'MDL': 17.5825, 'MGA': 4324.8508, 'MKD': 54.0436, 'MMK': 2099.5984, 'MNT': 3564.3844, 'MOP': 8.0775, 'MRU': 40.1288, 'MUR': 47.4307, 'MVR': 15.4684, 'MWK': 1733.3964, 'MXN': 17.4504, 'MYR': 4.0912, 'MZN': 63.5375, 'NAD': 16.7671, 'NGN': 1366.5907, 'NIO': 36.8211, 'NOK': 9.5783, 'NPR': 154.6103, 'NZD': 1.7256, 'OMR': 0.3845, 'PAB': 1.0, 'PEN': 3.4045, 'PGK': 4.4389, 'PHP': 61.7948, 'PKR': 278.0807, 'PLN': 3.7911, 'PYG': 6052.9232, 'QAR': 3.64, 'RON': 4.5995, 'RSD': 103.2005, 'RUB': 77.8264, 'RWF': 1468.7607, 'SAR': 3.75, 'SBD': 8.0327, 'SCR': 14.5792, 'SDG': 458.4797, 'SEK': 9.6999, 'SGD': 1.29, 'SHP': 0.7496, 'SLE': 24.3641, 'SLL': 24364.1441, 'SOS': 571.3614, 'SRD': 37.9724, 'SSP': 4900.2076, 'STN': 21.5116, 'SYP': 121.7792, 'SZL': 16.7671, 'THB': 33.6573, 'TJS': 9.2356, 'TMT': 3.5004, 'TND': 2.9551, 'TOP': 2.3722, 'TRY': 47.342, 'TTD': 6.7997, 'TVD': 1.4306, 'TWD': 32.3549, 'TZS': 2631.0175, 'UAH': 44.8542, 'UGX': 3736.836, 'UYU': 40.2303, 'UZS': 11913.7478, 'VES': 742.2292, 'VND': 26240.0163, 'VUV': 118.5531, 'WST': 2.7162, 'XAF': 575.9466, 'XCD': 2.7, 'XCG': 1.79, 'XDR': 0.7372, 'XOF': 575.9466, 'XPF': 104.7765, 'YER': 238.2144, 'ZAR': 16.7629, 'ZMW': 18.6658, 'ZWG': 26.6503, 'ZWL': 26.6503}
# ---------------------------------------------------------

# %%
messages
# Out:
# [HumanMessage(content='What is the conversion factor between usd and inr and based on that can u convert 10 usd to inr', additional_kwargs={}, response_metadata={}),
#  ToolMessage(content='{"result": "success", "documentation": "https://www.exchangerate-api.com/docs", "terms_of_use": "https://www.exchangerate-api.com/terms", "time_last_update_unix": 1785110401, "time_last_update_utc": "Mon, 27 Jul 2026 00:00:01 +0000", "time_next_update_unix": 1785196801, "time_next_update_utc": "Tue, 28 Jul 2026 00:00:01 +0000", "base_code": "USD", "conversion_rates": {"USD": 1, "AED": 3.6725, "AFN": 66.022, "ALL": 82.3937, "AMD": 365.8114, "ANG": 1.79, "AOA": 921.3527, "ARS": 1494.3744, "AUD": 1.4304, "AWG": 1.79, "AZN": 1.7009, "BAM": 1.7173, "BBD": 2.0, "BDT": 123.6077, "BGN": 1.7173, "BHD": 0.376, "BIF": 2990.8731, "BMD": 1.0, "BND": 1.2902, "BOB": 11.1515, "BRL": 5.0861, "BSD": 1.0, "BT